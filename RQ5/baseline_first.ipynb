# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.meta.preprocessor.preprocessors import FeatureEngineer
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.config import INDICATORS
from stable_baselines3.common.vec_env import DummyVecEnv

# Additional imports needed for RL with exploration strategies
from stable_baselines3 import PPO, A2C, DDPG, TD3, SAC
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
from stable_baselines3.common.evaluation import evaluate_policy
import matplotlib.pyplot as plt

# %% [markdown]
# Data Preprocessing

# %%
# Load and preprocess EUR/USD Forex data for FinRL

# Load CSV
df = pd.read_csv("data/eurusd_hourly.csv")

# Rename columns to FinRL-compatible format
df = df.rename(columns={
    'Gmt time': 'date',
    'Open': 'open',
    'High': 'high',
    'Low': 'low',
    'Close': 'close',
    'Volume': 'volume'
})

# Convert date to datetime object
df['date'] = pd.to_datetime(df['date'], format='%d.%m.%Y %H:%M:%S.%f')

# Add a ticker symbol (required even for one asset)
df['tic'] = 'EURUSD'

# Reorder columns
df = df[['date', 'tic', 'open', 'high', 'low', 'close', 'volume']]

# Drop any rows with missing values
df = df.dropna()

# Feature Engineering
fe = FeatureEngineer(
    use_technical_indicator=True,
    tech_indicator_list=INDICATORS,  # e.g. macd, rsi_30, etc.
    use_turbulence=False,
    user_defined_feature=False
)

# Apply feature engineering
df_processed = fe.preprocess_data(df)

# Show processed head to verify
df_processed.head()
# Out:
# Successfully added technical indicators
#                  date     tic     open     high      low    close     volume  \
# 0 2023-01-01 22:00:00  EURUSD  1.06970  1.07066  1.06788  1.06929  2477.4199
# 1 2023-01-01 23:00:00  EURUSD  1.06896  1.07047  1.06829  1.07005  4932.9600
# 2 2023-01-02 00:00:00  EURUSD  1.07007  1.07058  1.06912  1.07040  3522.1299
# 3 2023-01-02 01:00:00  EURUSD  1.07041  1.07087  1.06919  1.06977   432.2800
# 4 2023-01-02 02:00:00  EURUSD  1.06977  1.06977  1.06862  1.06904  1581.3000
#
#        macd   boll_ub   boll_lb      rsi_30      cci_30       dx_30  \
# 0  0.000000  1.070745  1.068595  100.000000   66.666667  100.000000
# 1  0.000017  1.070745  1.068595  100.000000   66.666667  100.000000
# 2  0.000033  1.071048  1.068778  100.000000  100.000000  100.000000
# 3  0.000016  1.070815  1.068940   62.466736   55.724417  100.000000
# 4 -0.000022  1.070815  1.068605   43.083297  -97.578348   21.592914
#
#    close_30_sma  close_60_sma
# 0      1.069290      1.069290
# 1      1.069670      1.069670
# 2      1.069913      1.069913
# 3      1.069878      1.069878
# 4      1.069710      1.069710

# %% [markdown]
# Data Split

# %%
# Chronologically split the dataset 80% train / 20% test
split_index = int(len(df_processed) * 0.8)

train_df = df_processed.iloc[:split_index]
test_df = df_processed.iloc[split_index:]

# Set up environment parameters
stock_dimension = len(train_df['tic'].unique())  # Should be 1 (EURUSD)
state_space = 1 + 2 * stock_dimension + len(INDICATORS) * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 100000,
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4,
    "num_stock_shares": [0] * stock_dimension  # Initial holdings (0 for each asset)
}

# Create the training environment 
env_train = DummyVecEnv([lambda: StockTradingEnv(train_df, **env_kwargs)])

# (Optional) Print environment info
print(f"Training set length: {len(train_df)}, Testing set length: {len(test_df)}")
print("State space:", state_space)
# Out:
# Training set length: 10040, Testing set length: 2511
# State space: 11

# %% [markdown]
# Training

# %%
from stable_baselines3 import DQN

model_dqn = DQN(
    policy="MlpPolicy",
    env=env_train,
    learning_rate=1e-4,
    buffer_size=10_000,
    learning_starts=100,
    batch_size=32,
    tau=1.0,
    gamma=0.99, 
    train_freq=(1, "step"),
    target_update_interval=250,
    exploration_fraction=0.1,
    exploration_initial_eps=1.0,
    exploration_final_eps=0.01,
    policy_kwargs=dict(net_arch=[64, 64]),
    verbose=1,
    tensorboard_log="./dqn_eurusd_tensorboard/"
)

model_dqn.learn(total_timesteps=50_000)
# Out:
# Using cpu device
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 from stable_baselines3 import DQN
# ----> 3 model_dqn = DQN(
#       4     policy="MlpPolicy",
#       5     env=env_train,
#       6     learning_rate=1e-4,
#       7     buffer_size=10_000,
#       8     learning_starts=100,
#       9     batch_size=32,
#      10     tau=1.0,
#      11     gamma=0.99,
#      12     train_freq=(1, "step"),
#      13     target_update_interval=250,
#      14     exploration_fraction=0.1,
#      15     exploration_initial_eps=1.0,
#      16     exploration_final_eps=0.01,
#      17     policy_kwargs=dict(net_arch=[64, 64]),
#      18     verbose=1,
#      19     tensorboard_log="./dqn_eurusd_tensorboard/"
#      20 )
#      22 model_dqn.learn(total_timesteps=50_000)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\dqn\dqn.py:104, in DQN.__init__(self, policy, env, learning_rate, buffer_size, learning_starts, batch_size, tau, gamma, train_freq, gradient_steps, replay_buffer_class, replay_buffer_kwargs, optimize_memory_usage, target_update_interval, exploration_fraction, exploration_initial_eps, exploration_final_eps, max_grad_norm, stats_window_size, tensorboard_log, policy_kwargs, verbose, seed, device, _init_setup_model)
#      76 def __init__(
#      77     self,
#      78     policy: Union[str, type[DQNPolicy]],
#    (...)
#     102     _init_setup_model: bool = True,
#     103 ) -> None:
# --> 104     super().__init__(
#     105         policy,
#     106         env,
#     107         learning_rate,
#     108         buffer_size,
#     109         learning_starts,
#     110         batch_size,
#     111         tau,
#     112         gamma,
#     113         train_freq,
#     114         gradient_steps,
#     115         action_noise=None,  # No action noise
#     116         replay_buffer_class=replay_buffer_class,
#     117         replay_buffer_kwargs=replay_buffer_kwargs,
#     118         policy_kwargs=policy_kwargs,
#     119         stats_window_size=stats_window_size,
#     120         tensorboard_log=tensorboard_log,
#     121         verbose=verbose,
#     122         device=device,
#     123         seed=seed,
#     124         sde_support=False,
#     125         optimize_memory_usage=optimize_memory_usage,
#     126         supported_action_spaces=(spaces.Discrete,),
#     127         support_multi_env=True,
#     128     )
#     130     self.exploration_initial_eps = exploration_initial_eps
#     131     self.exploration_final_eps = exploration_final_eps
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:110, in OffPolicyAlgorithm.__init__(self, policy, env, learning_rate, buffer_size, learning_starts, batch_size, tau, gamma, train_freq, gradient_steps, action_noise, replay_buffer_class, replay_buffer_kwargs, optimize_memory_usage, policy_kwargs, stats_window_size, tensorboard_log, verbose, device, support_multi_env, monitor_wrapper, seed, use_sde, sde_sample_freq, use_sde_at_warmup, sde_support, supported_action_spaces)
#      80 def __init__(
#      81     self,
#      82     policy: Union[str, type[BasePolicy]],
#    (...)
#     108     supported_action_spaces: Optional[tuple[type[spaces.Space], ...]] = None,
#     109 ):
# --> 110     super().__init__(
#     111         policy=policy,
#     112         env=env,
#     113         learning_rate=learning_rate,
#     114         policy_kwargs=policy_kwargs,
#     115         stats_window_size=stats_window_size,
#     116         tensorboard_log=tensorboard_log,
#     117         verbose=verbose,
#     118         device=device,
#     119         support_multi_env=support_multi_env,
#     120         monitor_wrapper=monitor_wrapper,
#     121         seed=seed,
#     122         use_sde=use_sde,
#     123         sde_sample_freq=sde_sample_freq,
#     124         supported_action_spaces=supported_action_spaces,
#     125     )
#     126     self.buffer_size = buffer_size
#     127     self.batch_size = batch_size
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\base_class.py:181, in BaseAlgorithm.__init__(self, policy, env, learning_rate, policy_kwargs, stats_window_size, tensorboard_log, verbose, device, support_multi_env, monitor_wrapper, seed, use_sde, sde_sample_freq, supported_action_spaces)
#     178 self._vec_normalize_env = unwrap_vec_normalize(env)
#     180 if supported_action_spaces is not None:
# --> 181     assert isinstance(self.action_space, supported_action_spaces), (
#     182         f"The algorithm only supports {supported_action_spaces} as action spaces "
#     183         f"but {self.action_space} was provided"
#     184     )
#     186 if not support_multi_env and self.n_envs > 1:
#     187     raise ValueError(
#     188         "Error: the model does not support multiple envs; it requires " "a single vectorized environment."
#     189     )
#
# AssertionError: The algorithm only supports (<class 'gymnasium.spaces.discrete.Discrete'>,) as action spaces but Box(-1.0, 1.0, (1,), float32) was provided
